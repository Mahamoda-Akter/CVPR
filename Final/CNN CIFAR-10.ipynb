# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import os

# Ignore information messages from TensorFlow
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# directory paths
test_data_dir = 'E:/CIFAR-10-images/test'
train_data_dir = 'E:/CIFAR-10-images/train'

# Load CIFAR-10 dataset
(_, _), (X_test, Y_test) = cifar10.load_data()

# Load custom train dataset
train_datagen = keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(32, 32),
    batch_size=32,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

X_test, Y_test = X_test / 255.0, to_categorical(Y_test)

# Build a CNN model
def build_cnn_model(optimizer_name):
    model = keras.Sequential([
        keras.Input(shape=(32, 32, 3)),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    
    model.compile(
        optimizer=optimizer_name,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# List of optimizers to try
optimizers = ['adam', 'sgd', 'rmsprop']

# Train and evaluate models with different optimizers
for optimizer_name in optimizers:
    model = build_cnn_model(optimizer_name)
    
    print(f"\n\nTraining with optimizer: {optimizer_name}")
    history = model.fit(train_generator, epochs=10, validation_data=(X_test, Y_test), verbose=1)
    
    # Evaluate the model on the test set
    test_loss, test_acc = model.evaluate(X_test, Y_test, verbose=0)
    print(f'\n\nTest accuracy with {optimizer_name}: {test_acc}')
# Out:
# Found 50000 images belonging to 10 classes.
#
#
# Training with optimizer: adam
# Epoch 1/10
# 1563/1563 [==============================] - 486s 310ms/step - loss: 1.5681 - accuracy: 0.4284 - val_loss: 1.2378 - val_accuracy: 0.5562
# Epoch 2/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.2323 - accuracy: 0.5628 - val_loss: 1.1154 - val_accuracy: 0.6013
# Epoch 3/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1062 - accuracy: 0.6104 - val_loss: 1.0126 - val_accuracy: 0.6489
# Epoch 4/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.0147 - accuracy: 0.6442 - val_loss: 0.9824 - val_accuracy: 0.6586
# Epoch 5/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 0.9621 - accuracy: 0.6638 - val_loss: 1.0172 - val_accuracy: 0.6499
# Epoch 6/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.9233 - accuracy: 0.6779 - val_loss: 0.8814 - val_accuracy: 0.6909
# Epoch 7/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8895 - accuracy: 0.6875 - val_loss: 0.8909 - val_accuracy: 0.6963
# Epoch 8/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8612 - accuracy: 0.6973 - val_loss: 0.9918 - val_accuracy: 0.6723
# Epoch 9/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.8331 - accuracy: 0.7097 - val_loss: 0.8574 - val_accuracy: 0.7070
# Epoch 10/10
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.8170 - accuracy: 0.7158 - val_loss: 0.8261 - val_accuracy: 0.7130
#
#
# Test accuracy with adam: 0.7129999995231628
#
#
# Training with optimizer: sgd
# Epoch 1/10
# 1563/1563 [==============================] - 45s 28ms/step - loss: 2.0555 - accuracy: 0.2404 - val_loss: 1.9353 - val_accuracy: 0.3090
# Epoch 2/10
# 1563/1563 [==============================] - 45s 29ms/step - loss: 1.7058 - accuracy: 0.3812 - val_loss: 1.5939 - val_accuracy: 0.4229
# Epoch 3/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.5406 - accuracy: 0.4435 - val_loss: 1.4250 - val_accuracy: 0.4837
# Epoch 4/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 1.4460 - accuracy: 0.4802 - val_loss: 1.3867 - val_accuracy: 0.5024
# Epoch 5/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.3788 - accuracy: 0.5102 - val_loss: 1.2803 - val_accuracy: 0.5402
# Epoch 6/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.3162 - accuracy: 0.5333 - val_loss: 1.2202 - val_accuracy: 0.5665
# Epoch 7/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.2583 - accuracy: 0.5559 - val_loss: 1.1847 - val_accuracy: 0.5781
# Epoch 8/10
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.2110 - accuracy: 0.5742 - val_loss: 1.1283 - val_accuracy: 0.5993
# Epoch 9/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1723 - accuracy: 0.5875 - val_loss: 1.1363 - val_accuracy: 0.5991
# Epoch 10/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 1.1333 - accuracy: 0.6012 - val_loss: 1.1314 - val_accuracy: 0.6072
#
#
# Test accuracy with sgd: 0.607200026512146
#
#
# Training with optimizer: rmsprop
# Epoch 1/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.6176 - accuracy: 0.4176 - val_loss: 1.4205 - val_accuracy: 0.5037
# Epoch 2/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.2653 - accuracy: 0.5543 - val_loss: 1.1138 - val_accuracy: 0.6074
# Epoch 3/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 1.1257 - accuracy: 0.6063 - val_loss: 1.0175 - val_accuracy: 0.6483
# Epoch 4/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 1.0341 - accuracy: 0.6393 - val_loss: 1.0213 - val_accuracy: 0.6565
# Epoch 5/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.9759 - accuracy: 0.6621 - val_loss: 0.9105 - val_accuracy: 0.6834
# Epoch 6/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.9378 - accuracy: 0.6767 - val_loss: 0.9615 - val_accuracy: 0.6715
# Epoch 7/10
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.9056 - accuracy: 0.6884 - val_loss: 0.9707 - val_accuracy: 0.6844
# Epoch 8/10
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.8788 - accuracy: 0.6964 - val_loss: 0.8745 - val_accuracy: 0.7061
# Epoch 9/10
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8745 - accuracy: 0.7017 - val_loss: 0.8778 - val_accuracy: 0.7097
# Epoch 10/10
# 1563/1563 [==============================] - 43s 28ms/step - loss: 0.8615 - accuracy: 0.7077 - val_loss: 0.9227 - val_accuracy: 0.7000
#
#
# Test accuracy with rmsprop: 0.699999988079071
